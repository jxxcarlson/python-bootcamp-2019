# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
t = np.arange(0.0, 2.01, 0.01)
y = np.sin(10*np.pi*t)
plt.plot(y) 
plt.savefig('sine.png')

# %%
list(map(lambda x: round(x,3), y[:8]))
# Out:
# [0.0, 0.309, 0.588, 0.809, 0.951, 1.0, 0.951, 0.809]

# %%
FREQUENCY = 440             # Hertz
AMPLITUDE = 255             # Max 255
DURATION = 2                # seconds
SAMPLERATE = 44100          # Don't change
FILENAME = 'sine.wav'       # up to you
index = np.arange(SAMPLESIZE)
index
# Out:
# array([    0,     1,     2, ..., 44097, 44098, 44099])

# %%
samples = AMPLITUDE*np.sin(2 * np.pi * FREQUENCY * index / SAMPLERATE)
list(map(lambda x: round(x,3), samples[0:5]))
# Out:
# [0.0, 15.975, 31.888, 47.675, 63.275]

# %%
samples = AMPLITUDE*np.sin(2 * np.pi * freq * index / SAMPLERATE)
